# %%
import torch
import torch.nn.functional as F
from torchvision import datasets,transforms
from torch import nn
import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %%
transform_train = transforms.Compose([transforms.Resize((32,32)),  #resises the image so it can be perfect for our model.
                                      transforms.RandomHorizontalFlip(), # FLips the image w.r.t horizontal axis
                                      transforms.RandomRotation(10),     #Rotates the image to a specified angel
                                      transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)), #Performs actions like zooms, change shear angles.
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # Set the color params
                                      transforms.ToTensor(), # comvert the image to tensor so that it can work with torch
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) #Normalize all the images
                               ])
 
 
transform = transforms.Compose([transforms.Resize((32,32)),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])
training_aug = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train) # Data augmentation is only done on training images
training_ori = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
validation_1 = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
validation_2 = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

training_dataset = torch.utils.data.ConcatDataset([training_aug, training_ori])
validation_dataset = torch.utils.data.ConcatDataset([validation_1, validation_2])

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=100, shuffle=True) # Batch size of 100 i.e to work with 100 images at a time
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 100, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(len(training_dataset))
print(len(validation_dataset))
# Out:
# 100000
# 20000

# %%
# We need to convert the images to numpy arrays as tensors are not compatible with matplotlib.
def im_convert(tensor):  
    image = tensor.cpu().clone().detach().numpy() # This process will happen in normal cpu.
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    image = image.clip(0, 1)
    return image

# %%
# Different classes in CIPHAR 10 dataset. 
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We iter the batch of images to display
dataiter = iter(training_loader) # converting our train_dataloader to iterable so that we can iter through it. 
images, labels = dataiter.next() #going from 1st batch of 100 images to the next batch
fig = plt.figure(figsize=(25, 4)) 

# We plot 20 images from our train_dataset
for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[]) 
    plt.imshow(im_convert(images[idx])) #converting to numpy array as plt needs it.
    ax.set_title(classes[labels[idx].item()])

# %%
class LeNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1) # input is color image, hence 3 i/p channels. 16 filters, kernal size is tuned to 3 to avoid overfitting, stride is 1 , padding is 1 extract all edge features
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1) # We double the feature maps for every conv layer as in pratice it is really good.
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv5 = nn.Conv2d(64, 128, 3, 1, padding=1)
        self.conv6 = nn.Conv2d(128, 128, 3, 1, padding=1)
        self.conv7 = nn.Conv2d(128, 256, 3, 1, padding=1)
        #self.conv8 = nn.Conv2d(256, 256, 3, 1, padding=1)
        self.fc1 = nn.Linear(2*2*256, 64) # I/p image size is 32*32, after 3 MaxPooling layers it reduces to 4*4 and 64 because our last conv layer has 64 outputs. Output nodes is 500
        self.fc2 = nn.Linear(64, 32)
        #self.fc3 = nn.Linear(64, 32)
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.3)

        self.fc3 = nn.Linear(32, 10) # output nodes are 10 because our dataset have 10 different categories
    def forward(self, x):
        x = F.relu(self.conv1(x)) #Apply relu to each output of conv layer.
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2) # Max pooling layer with kernal of 2 and stride of 2
        
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.max_pool2d(x, 2, 2)
        
        
        x = F.relu(self.conv7(x))
        #x = F.relu(self.conv8(x))
        x = F.max_pool2d(x, 2, 2)
        x = self.dropout1(x)
        
        x = x.view(-1, 2*2*256) # flatten our images to 1D to input it to the fully connected layers
        x = F.relu(self.fc1(x))
        x = self.dropout2(x) # Applying dropout b/t layers which exchange highest parameters. This is a good practice
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        #x = F.relu(self.fc3(x))
                   
        x = self.fc3(x)
        return x

# %%
model = LeNet().to(device) # run our model on cuda GPU for faster results
model
# Out:
# LeNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss() # same as categorical_crossentropy loss used in Keras models which runs on Tensorflow
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001) # fine tuned the lr

# %%
# PATH = "my_model3.pth"
# checkpoint = torch.load(PATH)
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']
# loss = checkpoint['loss']

# %%
epochs = 50
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs): # training our model, put input according to every batch.
  
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0

    for inputs, labels in training_loader:
        inputs = inputs.to(device) # input to device as our model is running in mentioned device.
        labels = labels.to(device)
        outputs = model(inputs) # every batch of 100 images are put as an input.
        loss = criterion(outputs, labels) # Calc loss after each batch i/p by comparing it to actual labels. 

        optimizer.zero_grad() #setting the initial gradient to 0
        loss.backward() # backpropagating the loss
        optimizer.step() # updating the weights and bias values for every single step.

        _, preds = torch.max(outputs, 1) # taking the highest value of prediction.
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data) # calculating te accuracy by taking the sum of all the correct predictions in a batch.

    else:
        with torch.no_grad(): # we do not need gradient for validation.
            for val_inputs, val_labels in validation_loader:
                val_inputs = val_inputs.to(device)
                val_labels = val_labels.to(device)
                val_outputs = model(val_inputs)
                val_loss = criterion(val_outputs, val_labels)

                _, val_preds = torch.max(val_outputs, 1)
                val_running_loss += val_loss.item()
                val_running_corrects += torch.sum(val_preds == val_labels.data)

        epoch_loss = running_loss/len(training_loader) # loss per epoch
        epoch_acc = running_corrects.float()/ len(training_loader) # accuracy per epoch
        running_loss_history.append(epoch_loss) # appending for displaying 
        running_corrects_history.append(epoch_acc)

        val_epoch_loss = val_running_loss/len(validation_loader)
        val_epoch_acc = val_running_corrects.float()/ len(validation_loader)
        val_running_loss_history.append(val_epoch_loss)
        val_running_corrects_history.append(val_epoch_acc)
        print('epoch :', (e+1))
        print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
        print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# epoch : 1
# training loss: 1.8146, acc 29.1470
# validation loss: 1.5249, validation acc 41.2750
# epoch : 2
# training loss: 1.4316, acc 47.1110
# validation loss: 1.2834, validation acc 53.8300
# epoch : 3
# training loss: 1.2154, acc 57.3820
# validation loss: 1.1100, validation acc 62.5200
# epoch : 4
# training loss: 1.0570, acc 63.8370
# validation loss: 0.9738, validation acc 67.5200
# epoch : 5
# training loss: 0.9616, acc 67.4860
# validation loss: 0.9057, validation acc 70.2400
# epoch : 6
# training loss: 0.8915, acc 70.2900
# validation loss: 0.8281, validation acc 72.8550
# epoch : 7
# training loss: 0.8378, acc 72.1200
# validation loss: 0.8499, validation acc 73.0650
# epoch : 8
# training loss: 0.8000, acc 73.6170
# validation loss: 0.7796, validation acc 75.5300
# epoch : 9
# training loss: 0.7628, acc 75.0770
# validation loss: 0.8029, validation acc 74.9800
# epoch : 10
# training loss: 0.7254, acc 76.4440
# validation loss: 0.7375, validation acc 77.3950
# epoch : 11
# training loss: 0.6975, acc 77.2430
# validation loss: 0.7781, validation acc 76.1750
# epoch : 12
# training loss: 0.6821, acc 77.9740
# validation loss: 0.7172, validation acc 77.6950
# epoch : 13
# training loss: 0.6578, acc 78.7030
# validation loss: 0.7416, validation acc 77.2450
# epoch : 14
# training loss: 0.6416, acc 79.3420
# validation loss: 0.7091, validation acc 78.6300
# epoch : 15
# training loss: 0.6279, acc 79.7840
# validation loss: 0.6796, validation acc 79.3350
# epoch : 16
# training loss: 0.6149, acc 80.3390
# validation loss: 0.6958, validation acc 79.7450
# epoch : 17
# training loss: 0.6108, acc 80.5440
# validation loss: 0.7084, validation acc 79.4850
# epoch : 18
# training loss: 0.5928, acc 81.0490
# validation loss: 0.6708, validation acc 79.7100
# epoch : 19
# training loss: 0.5916, acc 81.1670
# validation loss: 0.6792, validation acc 79.8600
# epoch : 20
# training loss: 0.5718, acc 81.7640
# validation loss: 0.6647, validation acc 80.1000
# epoch : 21
# training loss: 0.5731, acc 81.8560
# validation loss: 0.6471, validation acc 80.6250
# epoch : 22
# training loss: 0.5529, acc 82.4500
# validation loss: 0.6897, validation acc 79.6500
# epoch : 23
# training loss: 0.5516, acc 82.4700
# validation loss: 0.6834, validation acc 80.1150
# epoch : 24
# training loss: 0.5441, acc 82.8970
# validation loss: 0.6560, validation acc 81.0350
# epoch : 25
# training loss: 0.5431, acc 82.9560
# validation loss: 0.6871, validation acc 80.0350
# epoch : 26
# training loss: 0.5344, acc 83.2320
# validation loss: 0.6891, validation acc 80.3450
# epoch : 27
# training loss: 0.5273, acc 83.2490
# validation loss: 0.6678, validation acc 81.2250
# epoch : 28
# training loss: 0.5211, acc 83.6750
# validation loss: 0.6530, validation acc 81.4650
# epoch : 29
# training loss: 0.5136, acc 83.8350
# validation loss: 0.6541, validation acc 81.2950
# epoch : 30
# training loss: 0.5119, acc 84.0350
# validation loss: 0.6732, validation acc 80.6700
# epoch : 31
# training loss: 0.5022, acc 84.3430
# validation loss: 0.6686, validation acc 81.3550
# epoch : 32
# training loss: 0.5017, acc 84.3070
# validation loss: 0.6677, validation acc 81.0700
# epoch : 33
# training loss: 0.4996, acc 84.3420
# validation loss: 0.6441, validation acc 82.0550
# epoch : 34
# training loss: 0.4971, acc 84.6030
# validation loss: 0.6373, validation acc 81.7600
# epoch : 35
# training loss: 0.4855, acc 84.9500
# validation loss: 0.6679, validation acc 81.7350
# epoch : 36
# training loss: 0.4885, acc 84.9430
# validation loss: 0.6408, validation acc 81.7150
# epoch : 37
# training loss: 0.4858, acc 85.0380
# validation loss: 0.6995, validation acc 81.5200
# epoch : 38
# training loss: 0.4789, acc 85.1390
# validation loss: 0.6622, validation acc 81.6500
# epoch : 39
# training loss: 0.4751, acc 85.3360
# validation loss: 0.7040, validation acc 80.8350
# epoch : 40
# training loss: 0.4748, acc 85.4200
# validation loss: 0.6845, validation acc 81.5500
# epoch : 41
# training loss: 0.4781, acc 85.2940
# validation loss: 0.6545, validation acc 82.6550
# epoch : 42
# training loss: 0.4691, acc 85.5660
# validation loss: 0.6889, validation acc 82.3600
# epoch : 43
# training loss: 0.4638, acc 85.6910
# validation loss: 0.6527, validation acc 82.3150
# epoch : 44
# training loss: 0.4644, acc 85.6990
# validation loss: 0.7099, validation acc 81.9300
# epoch : 45
# training loss: 0.4638, acc 85.7440
# validation loss: 0.6506, validation acc 82.1250
# epoch : 46
# training loss: 0.4618, acc 85.8690
# validation loss: 0.6743, validation acc 82.1450
# epoch : 47
# training loss: 0.4615, acc 85.9670
# validation loss: 0.6755, validation acc 81.5550
# epoch : 48
# training loss: 0.4593, acc 86.0340
# validation loss: 0.6812, validation acc 81.6600
# epoch : 49
# training loss: 0.4555, acc 86.0850
# validation loss: 0.6461, validation acc 82.2800
# epoch : 50
# training loss: 0.4647, acc 85.9400
# validation loss: 0.6633, validation acc 81.9100

# %%
torch.save({
            'epoch': e+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': epoch_loss,
            }, "my_model3_continue.pth")

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 645130
